# %% [markdown]
# # p0=None Efficiency Plots for Ising-like dynamical Bnet
#
# For p0=None,
#
# We produce lattice plots for various betta_jj and a final parametric plot for our 2-dim Ising-like dynamical bnet.
#
# p0=None means p0 is assigned at random for each node, from a uniform distribution from 0 to 1

# %%
# this makes sure it starts looking for things from the Bayes_Petri_Net folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bnet_rg

# %%
from  Net import *

# %% [markdown]
# # p0 = None

# %%
beta_jj = BETA_JJ_CURIE * 20
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj / BETA_JJ_CURIE
num_iter = 10

p0 = None
h=0
lam=0
param_to_x_y = dict()
beta_hat_to_mag= dict()
net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
#param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
#beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=0.02039, av_eff=0.76440
# 2, mag=0.04045, av_eff=0.78443
# 3, mag=0.05247, av_eff=0.78687
# 4, mag=0.06149, av_eff=0.79574
# 5, mag=0.03964, av_eff=0.79533
# 6, mag=0.03156, av_eff=0.81608
# 7, mag=-0.02175, av_eff=0.81830
# 8, mag=-0.00859, av_eff=0.85334
# 9, mag=-0.05381, av_eff=0.87076
# 10, mag=0.01671, av_eff=0.90638

# %%
beta_jj = BETA_JJ_CURIE * 20
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj / BETA_JJ_CURIE
num_iter = 5

p0 = None
h=0
lam=0
param_to_x_y = dict()
net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=0.10419, av_eff=0.76072
# 2, mag=0.14417, av_eff=0.77804
# 3, mag=0.19818, av_eff=0.78595
# 4, mag=0.25577, av_eff=0.78947
# 5, mag=0.31667, av_eff=0.79344

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 3
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj / BETA_JJ_CURIE
num_iter = 18

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=-0.02928, av_eff=0.50974
# 2, mag=-0.01627, av_eff=0.61183
# 3, mag=-0.01302, av_eff=0.61209
# 4, mag=-0.00325, av_eff=0.63262
# 5, mag=0.00957, av_eff=0.62127
# 6, mag=0.01810, av_eff=0.63293
# 7, mag=0.04561, av_eff=0.61733
# 8, mag=0.05259, av_eff=0.62349
# 9, mag=0.09665, av_eff=0.60322
# 10, mag=0.09437, av_eff=0.59843
# 11, mag=0.14733, av_eff=0.57341
# 12, mag=0.12203, av_eff=0.54294
# 13, mag=0.16084, av_eff=0.51671
# 14, mag=0.09095, av_eff=0.44399
# 15, mag=0.10906, av_eff=0.41998
# 16, mag=0.01408, av_eff=0.34247
# 17, mag=0.05296, av_eff=0.29101
# 18, mag=-0.02996, av_eff=0.26783

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 1
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj / BETA_JJ_CURIE
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=-0.04517, av_eff=0.21795
# 2, mag=-0.04327, av_eff=0.25306
# 3, mag=-0.04606, av_eff=0.25866
# 4, mag=-0.04765, av_eff=0.26051
# 5, mag=-0.04949, av_eff=0.26156
# 6, mag=-0.05239, av_eff=0.26211
# 7, mag=-0.05412, av_eff=0.26250
# 8, mag=-0.05769, av_eff=0.26271
# 9, mag=-0.05953, av_eff=0.26287
# 10, mag=-0.06357, av_eff=0.26293
# 11, mag=-0.06558, av_eff=0.26297
# 12, mag=-0.07006, av_eff=0.26296
# 13, mag=-0.07224, av_eff=0.26293
# 14, mag=-0.07716, av_eff=0.26287
# 15, mag=-0.07952, av_eff=0.26280
# 16, mag=-0.08489, av_eff=0.26270
# 17, mag=-0.08743, av_eff=0.26259
# 18, mag=-0.09326, av_eff=0.26246
# 19, mag=-0.09597, av_eff=0.26233
# 20, mag=-0.10228, av_eff=0.26218

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 0.5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj / BETA_JJ_CURIE
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=0.04116, av_eff=0.07169
# 2, mag=0.01810, av_eff=0.09183
# 3, mag=0.00942, av_eff=0.09364
# 4, mag=0.00487, av_eff=0.09409
# 5, mag=0.00319, av_eff=0.09424
# 6, mag=0.00181, av_eff=0.09431
# 7, mag=0.00132, av_eff=0.09433
# 8, mag=0.00078, av_eff=0.09434
# 9, mag=0.00058, av_eff=0.09435
# 10, mag=0.00035, av_eff=0.09435
# 11, mag=0.00026, av_eff=0.09435
# 12, mag=0.00016, av_eff=0.09435
# 13, mag=0.00012, av_eff=0.09435
# 14, mag=0.00007, av_eff=0.09435
# 15, mag=0.00005, av_eff=0.09435
# 16, mag=0.00003, av_eff=0.09435
# 17, mag=0.00002, av_eff=0.09435
# 18, mag=0.00001, av_eff=0.09435
# 19, mag=0.00001, av_eff=0.09436
# 20, mag=0.00001, av_eff=0.09441

# %%
plot_parametric_curve(param_to_x_y)

# %%
plot_x_to_y(beta_hat_to_mag)
