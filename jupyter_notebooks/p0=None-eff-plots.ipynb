# %% [markdown]
# # p0=None Efficiency Plots for Ising-like dynamical Bnet
#
# We plot the efficiency of our 2-dim Ising-like dynamical bnet for various temperatures and p0=None.
#
# p0=None means p0 is assigned at random for each node, from a uniform distribution from 0 to 1.

# %%
# this makes sure it starts looking for things from the Bayes_Petri_Net folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bnet_rg

# %%
from  Net import *

# %% [markdown]
# # p0 = None

# %%
beta_jj = BETA_JJ_CURIE * 20
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 10

p0 = None
h=0
lam=0
param_to_x_y = dict()
net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
#param_to_x_y[beta_jj]= net.get_av_cond_info_and_entropy()
# Out:
# 1, mag=0.10948, av_eff=0.74994
# 2, mag=0.17560, av_eff=0.77706
# 3, mag=0.26861, av_eff=0.78583
# 4, mag=0.37857, av_eff=0.79249
# 5, mag=0.51615, av_eff=0.79768
# 6, mag=0.67017, av_eff=0.81456
# 7, mag=0.81033, av_eff=0.82791
# 8, mag=0.92606, av_eff=0.86743
# 9, mag=0.97669, av_eff=0.88917
# 10, mag=0.99786, av_eff=undef

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 3
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 18

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_jj]= net.get_av_cond_info_and_entropy()
# Out:
# 1, mag=0.30299, av_eff=0.60244
# 2, mag=0.38690, av_eff=0.61973
# 3, mag=0.50626, av_eff=0.64099
# 4, mag=0.59879, av_eff=0.60847
# 5, mag=0.72233, av_eff=0.61538
# 6, mag=0.79634, av_eff=0.55056
# 7, mag=0.89404, av_eff=0.50806
# 8, mag=0.93197, av_eff=0.44651
# 9, mag=0.97952, av_eff=0.35322
# 10, mag=0.98752, av_eff=0.33009
# 11, mag=0.99598, av_eff=0.20914
# 12, mag=0.99665, av_eff=0.19869
# 13, mag=0.99736, av_eff=0.14885
# 14, mag=0.99742, av_eff=0.14187
# 15, mag=0.99747, av_eff=0.13536
# 16, mag=0.99747, av_eff=0.13457
# 17, mag=0.99748, av_eff=0.13405
# 18, mag=0.99748, av_eff=0.13399

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 1
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_jj]= net.get_av_cond_info_and_entropy()
# Out:
# 1, mag=-0.04951, av_eff=0.20501
# 2, mag=-0.02447, av_eff=0.24705
# 3, mag=-0.01946, av_eff=0.25618
# 4, mag=-0.01275, av_eff=0.25945
# 5, mag=-0.01087, av_eff=0.26109
# 6, mag=-0.00966, av_eff=0.26189
# 7, mag=-0.00874, av_eff=0.26250
# 8, mag=-0.00928, av_eff=0.26283
# 9, mag=-0.00863, av_eff=0.26311
# 10, mag=-0.00980, av_eff=0.26326
# 11, mag=-0.00920, av_eff=0.26339
# 12, mag=-0.01067, av_eff=0.26346
# 13, mag=-0.01005, av_eff=0.26351
# 14, mag=-0.01173, av_eff=0.26353
# 15, mag=-0.01105, av_eff=0.26353
# 16, mag=-0.01293, av_eff=0.26352
# 17, mag=-0.01217, av_eff=0.26350
# 18, mag=-0.01425, av_eff=0.26346
# 19, mag=-0.01341, av_eff=0.26343
# 20, mag=-0.01570, av_eff=0.26342

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 0.5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_jj]= net.get_av_cond_info_and_entropy()
# Out:
# 1, mag=-0.08191, av_eff=0.06904
# 2, mag=-0.05748, av_eff=0.09111
# 3, mag=-0.03940, av_eff=0.09339
# 4, mag=-0.02659, av_eff=0.09401
# 5, mag=-0.01813, av_eff=0.09422
# 6, mag=-0.01212, av_eff=0.09430
# 7, mag=-0.00825, av_eff=0.09433
# 8, mag=-0.00550, av_eff=0.09434
# 9, mag=-0.00374, av_eff=0.09435
# 10, mag=-0.00250, av_eff=0.09435
# 11, mag=-0.00170, av_eff=0.09435
# 12, mag=-0.00113, av_eff=0.09435
# 13, mag=-0.00077, av_eff=0.09435
# 14, mag=-0.00051, av_eff=0.09435
# 15, mag=-0.00035, av_eff=0.09435
# 16, mag=-0.00023, av_eff=0.09435
# 17, mag=-0.00016, av_eff=0.09435
# 18, mag=-0.00011, av_eff=0.09436
# 19, mag=-0.00007, av_eff=0.09437
# 20, mag=-0.00005, av_eff=0.09444

# %%
plot_parametric_curve(param_to_x_y)
