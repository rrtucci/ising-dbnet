# %% [markdown]
# # p0=0.5 Efficiency Plots for Ising-like dynamical Bnet
#
# For p0=0.5,
#
# We produce lattice plots for various betta_jj and a final parametric plot for our 2-dim Ising-like dynamical bnet

# %%
# this makes sure it starts looking for things from the Bayes_Petri_Net folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bnet_rg

# %%
from  Net import *

# %% [markdown]
# # p0 = 0.5

# %%
beta_jj = BETA_JJ_CURIE * 20
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj/BETA_JJ_CURIE
num_iter = 10

p0 = 0.5
h=0
lam=0
param_to_x_y = dict()
beta_hat_to_mag = dict()
net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=0.00000, av_eff=0.78500
# 2, mag=0.00000, av_eff=0.78500
# 3, mag=0.00000, av_eff=0.78500
# 4, mag=0.00000, av_eff=0.78500
# 5, mag=0.00000, av_eff=0.78500
# 6, mag=0.00000, av_eff=0.78500
# 7, mag=0.00000, av_eff=0.78500
# 8, mag=0.00000, av_eff=0.78500
# 9, mag=0.00000, av_eff=0.78500
# 10, mag=0.00000, av_eff=0.78500

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 3
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj/BETA_JJ_CURIE
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=0.00000, av_eff=0.64579
# 2, mag=0.00000, av_eff=0.64579
# 3, mag=0.00000, av_eff=0.64579
# 4, mag=0.00000, av_eff=0.64579
# 5, mag=0.00000, av_eff=0.64579
# 6, mag=0.00000, av_eff=0.64579
# 7, mag=0.00000, av_eff=0.64579
# 8, mag=0.00000, av_eff=0.64579
# 9, mag=0.00000, av_eff=0.64579
# 10, mag=0.00000, av_eff=0.64579
# 11, mag=0.00000, av_eff=0.64579
# 12, mag=0.00000, av_eff=0.64579
# 13, mag=0.00000, av_eff=0.64579
# 14, mag=0.00000, av_eff=0.64579
# 15, mag=0.00000, av_eff=0.64579
# 16, mag=0.00000, av_eff=0.64579
# 17, mag=0.00000, av_eff=0.64579
# 18, mag=0.00000, av_eff=0.64579
# 19, mag=0.00000, av_eff=0.64581
# 20, mag=0.00000, av_eff=0.64589

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 1
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj/BETA_JJ_CURIE
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=0.00000, av_eff=0.26401
# 2, mag=-0.00000, av_eff=0.26401
# 3, mag=-0.00000, av_eff=0.26401
# 4, mag=-0.00000, av_eff=0.26401
# 5, mag=-0.00000, av_eff=0.26401
# 6, mag=-0.00000, av_eff=0.26401
# 7, mag=-0.00000, av_eff=0.26401
# 8, mag=-0.00000, av_eff=0.26401
# 9, mag=-0.00000, av_eff=0.26401
# 10, mag=-0.00000, av_eff=0.26401
# 11, mag=-0.00000, av_eff=0.26401
# 12, mag=-0.00000, av_eff=0.26401
# 13, mag=-0.00000, av_eff=0.26401
# 14, mag=-0.00000, av_eff=0.26401
# 15, mag=-0.00000, av_eff=0.26401
# 16, mag=-0.00000, av_eff=0.26401
# 17, mag=-0.00000, av_eff=0.26401
# 18, mag=-0.00000, av_eff=0.26402
# 19, mag=-0.00000, av_eff=0.26403
# 20, mag=-0.00000, av_eff=0.26412

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 0.5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
beta_hat = beta_jj/BETA_JJ_CURIE
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.plot_lattice("test.txt")
param_to_x_y[beta_hat]= net.get_av_entropy_and_cond_info()
beta_hat_to_mag[beta_hat] = net.get_mag()
# Out:
# 1, mag=-0.00000, av_eff=0.09435
# 2, mag=-0.00000, av_eff=0.09435
# 3, mag=0.00000, av_eff=0.09435
# 4, mag=0.00000, av_eff=0.09435
# 5, mag=0.00000, av_eff=0.09435
# 6, mag=0.00000, av_eff=0.09435
# 7, mag=0.00000, av_eff=0.09435
# 8, mag=-0.00000, av_eff=0.09435
# 9, mag=0.00000, av_eff=0.09435
# 10, mag=0.00000, av_eff=0.09435
# 11, mag=0.00000, av_eff=0.09435
# 12, mag=0.00000, av_eff=0.09435
# 13, mag=0.00000, av_eff=0.09435
# 14, mag=0.00000, av_eff=0.09435
# 15, mag=0.00000, av_eff=0.09435
# 16, mag=-0.00000, av_eff=0.09435
# 17, mag=-0.00000, av_eff=0.09435
# 18, mag=0.00000, av_eff=0.09435
# 19, mag=0.00000, av_eff=0.09434
# 20, mag=0.00000, av_eff=0.09431

# %%
plot_parametric_curve(param_to_x_y)

# %%
plot_x_to_y(beta_hat_to_mag)
